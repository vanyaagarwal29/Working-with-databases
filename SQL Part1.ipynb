# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost', user='root', passwd="vanya7344")

# %%
mydb

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testvanya',),
#  ('testvanya1',)]

# %%
cursor.execute("create database testvanya1")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:516, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     515         query = query.encode('utf-8')
# --> 516     self._cmysql.query(query,
#     517                        raw=raw, buffered=buffered,
#     518                        raw_as_string=raw_as_string,
#     519                        query_attrs=self._query_attrs)
#     520 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Can't create database 'testvanya1'; database exists
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 cursor.execute("create database testvanya1")
#
# ...

# %%
cursor.execute('create table testvanya1.test(studentid INT(10), firstname VARCHAR(30), lastname VARCHAR(30), regid INT(10), classname VARCHAR(30))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:516, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     515         query = query.encode('utf-8')
# --> 516     self._cmysql.query(query,
#     517                        raw=raw, buffered=buffered,
#     518                        raw_as_string=raw_as_string,
#     519                        query_attrs=self._query_attrs)
#     520 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'test' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ...

# %%
cursor.execute('use testvanya1')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('test',)]

# %%
cursor.execute('insert into testvanya1.test values(12234,"vanya","agarwal",677,"fybdu")')

# %%
mydb.commit()

# %%
cursor.execute("select * from testvanya1.test")

# %%
cursor.fetchall()
# Out:
# [(12234, 'vanya', 'agarwal', 677, 'fybdu'),
#  (12234, 'vanya', 'agarwal', 677, 'fybdu')]

# %%
cursor.execute('create table testvanya1.glassdata(col1 INT(10), col2 float(10,5), col3 float(10,5), col4 float(10,5), col5 float(10,5), col6 float(10,5), col7 float(10,5), col8 float(10,5), col9 float(10,5), col10 float(10,5), col11 INT(10))')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:516, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     515         query = query.encode('utf-8')
# --> 516     self._cmysql.query(query,
#     517                        raw=raw, buffered=buffered,
#     518                        raw_as_string=raw_as_string,
#     519                        query_attrs=self._query_attrs)
#     520 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'glassdata' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ...

# %%
cursor.execute('use testvanya1')

# %%
cursor.execute('show tables')

# %%
cursor.fetchall()
# Out:
# [('glassdata',), ('test',)]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E4E7-041A
#
#  Directory of C:\Users\DELL
#
# 13-12-2022  20:29         2,461,386  Quora Question Pairs.ipynb
# 15-01-2023  16:28    <DIR>          .
# 26-12-2021  21:12    <DIR>          ..
# 15-09-2020  10:47    <DIR>          .android
# 15-01-2023  19:30    <DIR>          .conda
# 10-10-2021  13:44                25 .condarc
# 24-07-2020  13:52    <DIR>          .config
# 10-10-2021  13:43    <DIR>          .continuum
# 24-07-2020  13:52    <DIR>          .eclipse
# 15-01-2022  23:33                64 .gitconfig
# 15-09-2020  10:25    <DIR>          .idlerc
# 15-01-2023  12:04    <DIR>          .ipynb_checkpoints
# 10-10-2021  13:59    <DIR>          .ipython
# 11-10-2021  22:13    <DIR>          .jupyter
# 02-10-2021  21:48    <DIR>          .keras
# 23-06-2022  00:03                20 .lesshst
# 25-06-2022  11:47    <DIR>          .matplotlib
# 28-12-2021  12:25    <DIR>          .p2
# ...

# %%
file=open("glass.data","r")

# %%
file.read()
# Out:
# '1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1\n2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1\n3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1\n4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1\n5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1\n6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1\n7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1\n8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1\n9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1\n10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1\n11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1\n12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1\n13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1\n14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1\n15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1\n16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1\n17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1\n18,1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0.00,0.00,1
# ...

# %%
import csv
with open("glass.data",'r') as f:
    glass_data=csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print(i)
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1']
# ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1']
# ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1']
# ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1']
# ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1']
# ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1']
# ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1']
# ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1']
# ['16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1']
# ...

# %%
import csv
with open("glass.data",'r') as f:
    glass_data=csv.reader(f, delimiter = '\n')
    for i in glass_data:
        print(i)
        print(f'insert into glassdata1 values({str(i[0])})')
        cursor.execute(f'insert into testvanya1.glassdata values({str(i[0])})')
mydb.commit()
# Out:
# ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1']
# insert into glassdata1 values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)
# ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1']
# insert into glassdata1 values(2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1)
# ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1']
# insert into glassdata1 values(3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1)
# ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1']
# insert into glassdata1 values(4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1)
# ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1']
# insert into glassdata1 values(5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1)
# ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1']
# insert into glassdata1 values(6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1)
# ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1']
# ...

# %%
import pandas as pd
pd.read_sql("select * from testvanya1.glassdata",mydb)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6152\3885909961.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select * from testvanya1.glassdata",mydb)
#      col1     col2   col3  col4  col5   col6  col7  col8  col9  col10  col11
# 0       1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00    0.0      1
# 1       2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.0      1
# 2       3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.0      1
# 3       4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.0      1
# 4       5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.0      1
# ..    ...      ...    ...   ...   ...    ...   ...   ...   ...    ...    ...
# 209   210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.0      7
# ...
